# %% [markdown]
# <h1 style = "text-align:center;">US - NCHS DATASET</h1>

# %% [markdown]
# <h3 style = "text-align:center;">Data Analysis</h3>

# %% [markdown]
# <h4 style = "text-align:center;">December 6, 2023</h4>

# %% [markdown]
# <h5 style = "text-align:right;">Prepared by: Victor Odingo Odira</h5>

# %% [markdown]
# <h4 style = "text-align:left;">1. Import relevant libraries</h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# <h4 style = "text-align:left;">2. Load CSV data from the US National Center for Health Statistcs</h4>

# %%
data = pd.read_csv("NCHS.csv")
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %% [markdown]
# <h4 style = "text-align:left;">3. How may rows and columns are in the dataset?</h4>

# %%
# Method 1
print(f"Dataset has {data.shape[0]} rows and {data.shape[1]} columns")

# Method 2
print("Dataset has {} rows and {} columns".format(data.shape[0], data.shape[1]))
# Out:
# Dataset has 10296 rows and 6 columns
# Dataset has 10296 rows and 6 columns

# %% [markdown]
# <h4 style = "text-align:left;">4. Ascertain if the dataset has missing values (nan) </h4>

# %%
data.isna().sum()
# Out:
# Year                       0
# 113 Cause Name             0
# Cause Name                 0
# State                      0
# Deaths                     0
# Age-adjusted Death Rate    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Year                       False
# 113 Cause Name             False
# Cause Name                 False
# State                      False
# Deaths                     False
# Age-adjusted Death Rate    False
# dtype: bool

# %% [markdown]
# <h4 style = "text-align:left;">5. Remove all rows with na cases if any</h4>

# %%
data.dropna()
data.shape
# Out:
# (10296, 6)

# %% [markdown]
# <h4 style = "text-align:left;">6. What are the unique causes of death in the dataset?</h4>

# %%
causes_of_death = data["Cause Name"].unique()
print(causes_of_death)
# Out:
# ['Unintentional injuries' 'All causes' "Alzheimer's disease" 'Cancer'
#  'CLRD' 'Diabetes' 'Heart disease' 'Influenza and pneumonia'
#  'Kidney disease' 'Stroke' 'Suicide']

# %% [markdown]
# <h4 style = "text-align:left;">7. Remove "All causes" from the Cause Name Column</h4>

# %%
data = data[data["Cause Name"] != "All causes"]
causes_of_death = data["Cause Name"].unique()
print(causes_of_death)
# Out:
# ['Unintentional injuries' "Alzheimer's disease" 'Cancer' 'CLRD' 'Diabetes'
#  'Heart disease' 'Influenza and pneumonia' 'Kidney disease' 'Stroke'
#  'Suicide']

# %% [markdown]
# <h4 style = "text-align:left;">8. How many causes of death are in the dataset?</h4>

# %%
number_of_causes = len(causes_of_death)
print(f"Dataset has {number_of_causes} causes of death")
# Out:
# Dataset has 10 causes of death

# %% [markdown]
# <h4 style = "text-align:left;">9. What are the States which are affected by the causes of death?</h4>

# %%
affected_states = data["State"].unique()
print(affected_states)
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' 'United States']

# %% [markdown]
# <h4 style = "text-align:left;">10. Remove "United States" from the "State" Column</h4>

# %%
data = data[data["State"] != "United States"]
affected_states = data["State"].unique()
print(affected_states)
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %% [markdown]
# <h4 style = "text-align:left;">11. How many states are affected?</h4>

# %%
number_of_states = len(affected_states)
print("There are %s states affected in the dataset" %number_of_states)
# Out:
# There are 51 states affected in the dataset

# %% [markdown]
# <h4 style = "text-align:left;">12. What are the total
# number of deaths in the United States from 1999 to 2016?</h4>

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Year, 113 Cause Name, Cause Name, State, Deaths, Age-adjusted Death Rate]
# Index: []

# %%
total_deaths = data["Deaths"].sum()
print("%s deaths were registered between 1999 and 2016"%total_deaths)
# Out:
# 34199052 deaths were registered between 1999 and 2016

# %% [markdown]
# <h4 style = "text-align:left;">13. What are the number of deaths per year?</h4>

# %%
deaths_per_year = data.groupby("Year").sum()
print(deaths_per_year)
# Out:
#        Deaths  Age-adjusted Death Rate
# Year
# 1999  1905826                  35592.3
# 2000  1902194                  35161.3
# 2001  1899358                  34580.3
# 2002  1918873                  34429.2
# 2003  1912115                  33846.1
# 2004  1864133                  32397.1
# 2005  1889981                  32318.8
# 2006  1854676                  31152.8
# 2007  1846301                  30456.4
# 2008  1872981                  30342.3
# 2009  1838501                  29211.4
# 2010  1852349                  29052.7
# 2011  1869321                  28612.3
# 2012  1876588                  28067.9
# 2013  1910311                  27973.4
# 2014  1938408                  27914.7
# 2015  2013017                  28402.1
# 2016  2034119                  28183.5

# %% [markdown]
# <h4 style = "text-align:left;">14. What was trend of deaths per year?</h4>

# %%
plt.figure()
deaths_per_year["Deaths"].plot(color = "g")
plt.title("Yearly deaths from 1999 to 2016", fontsize = 14, fontname = "serif")
plt.xlabel("Year", fontsize = 10, fontname="serif")
plt.ylabel("Yearly deaths (in millions)", fontsize = 10, fontname = "serif")
plt.show()

# %% [markdown]
# <h4 style = "text-align:left;">15. Which 10 states had the highest number of deaths in all years?</h4>

# %%
data_df = data[data["State"] != "United States"]
dataset = data_df.groupby("State").sum()
dataset.sort_values("Deaths", ascending = False, inplace = True)
top_10 = dataset.head(10)
print(top_10)
# Out:
#                   Year   Deaths  Age-adjusted Death Rate
# State
# California      361350  3387500                   9902.4
# Florida         361350  2381013                   9934.1
# Texas           361350  2223113                  10970.2
# New York        361350  2147657                  10052.8
# Pennsylvania    361350  1755797                  11074.3
# Ohio            361350  1513814                  11729.3
# Illinois        361350  1427335                  10846.4
# Michigan        361350  1239287                  11468.1
# North Carolina  361350  1048219                  11408.7
# New Jersey      361350   975875                  10085.8

# %%
top_10["Deaths"].plot.bar()
plt.title("Top 10 States with the highest number of deaths", fontsize = 12, fontname = "fantasy")
plt.xlabel("State", fontsize = 10, fontname = "serif")
plt.ylabel("Number of deaths ('000,000)", fontsize = 10, fontname = "serif")
plt.show()

# %% [markdown]
# <h4 style = "text-align:left;">15. What were the 10 States the least number of deaths between 1999 and 2016?</h4>

# %%
data_df = data[data["State"] != "United States"]
dataset = data_df.groupby("State").sum()
dataset.sort_values("Deaths", ascending = False, inplace = True)
last_10 = dataset.tail(10)
print(last_10)
# Out:
#                         Year  Deaths  Age-adjusted Death Rate
# State
# Rhode Island          361350  133768                  10250.5
# Hawaii                361350  128375                   8428.9
# Montana               361350  118775                  10638.7
# Delaware              361350  102940                  10922.5
# South Dakota          361350  101420                  10540.1
# North Dakota          361350   83655                  10130.0
# Vermont               361350   73354                  10259.2
# District of Columbia  361350   66205                  11359.5
# Wyoming               361350   59399                  11029.3
# Alaska                361350   46983                  10460.2

# %% [markdown]
# <h4 style = "text-align:left;">15. What were the top causes of deaths in the United States between 1999 and 2016?</h4>

# %%
data_df = data[data["Cause Name"] != "All causes"]
dataset2 = data_df.groupby("Cause Name").sum()
dataset2.sort_values("Deaths", ascending = False, inplace = True)
top_10_causes = dataset2.head(10)
print(top_10_causes)
# Out:
#                             Year    Deaths  Age-adjusted Death Rate
# Cause Name
# Heart disease            1842885  11575183                 183332.8
# Cancer                   1842885  10244536                 165173.3
# Stroke                   1842885   2580140                  42568.0
# CLRD                     1842885   2434726                  41020.0
# Unintentional injuries   1842885   2177884                  39384.4
# Alzheimer's disease      1842885   1373412                  22620.0
# Diabetes                 1842885   1316379                  21555.8
# Influenza and pneumonia  1842885   1038969                  16881.3
# Kidney disease           1842885    807980                  12981.0
# Suicide                  1842885    649843                  12178.0

# %%
top_10_causes["Deaths"].plot.pie(autopct = "%.1f%%")
# Out:
# <AxesSubplot:ylabel='Deaths'>
